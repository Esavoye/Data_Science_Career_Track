# %% [markdown]
# # Springboard--DSC Program
#
# # Capstone Project 1 - Exploratory Data Analysis
# ### by Ellen A. Savoye

# %% [markdown]
# Previously, we cleaned up the text data by converting to lower case, and removing emojis, emoticons, punctuation, and special characters. The output was pickled for further use.

# %% [markdown]
# ### Import packages and data

# %%
# !pip install wordcloud

# %%
import pandas as pd
import numpy as np
import itertools
import collections

# libraries for NLP
import spacy

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

import re
import unicodedata

import string
from string import punctuation

import swifter

# libraries for getting and moving data
import os
from os import path
import shutil
from zipfile import ZipFile

# for Images
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# necessary dependencies for text pre-processing

nlp = spacy.load('en_core_web_sm', parse=True, tag=True, entity=True)
#nlp_vec = spacy.load('en_vecs', parse = True, tag=True, #entity=True)
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

# %%
# Set directories
src = "C:\\Users\\ellen\\Documents\\GitHub\\Data_Science_Career_Track\\Capstone_1\\Code\\"
dst = "C:\\Users\\ellen\\Documents\\GitHub\\Data_Science_Career_Track\\Capstone_1\\Data\\"

# Work computer
# src = "C:\\Users\\esavoye\\Documents\\GitHub\\Data_Science_Career_Track\\Capstone_1\\Code\\"
# dst = "C:\\Users\\esavoye\\Documents\\GitHub\\Data_Science_Career_Track\\Capstone_1\\Data\\"

# Create pickle file for use in the future

unpickled_df = pd.read_pickle(dst + '/slimmed_subset_df.pkl')

# %%
unpickled_df.head()
# Out:
#         id    target                                       comment_text  \
# 4    59856  0.893617               haha you guys are a bunch of losers.
# 11  239579  0.440000  This is a great story. Man. I wonder if the pe...
# 19  239592  0.500000  Angry trolls, misogynists and Racists", oh my....
# 20  239593  0.000000  Nice to some attempts to try to make comments ...
# 31  239607  0.912500  Yet call out all Muslims for the acts of a few...
#
#     severe_toxicity   obscene  identity_attack   insult  threat  asian  \
# 4          0.021277  0.000000         0.021277  0.87234  0.0000    0.0
# 11         0.000000  0.293333         0.000000  0.32000  0.0000    0.0
# 19         0.000000  0.000000         0.100000  0.50000  0.0000    0.0
# 20         0.000000  0.000000         0.000000  0.00000  0.0000    0.0
# 31         0.050000  0.237500         0.612500  0.88750  0.1125    0.0
#
#     atheist  ...    rating  funny  wow  sad  likes  disagree  sexual_explicit  \
# ...

# %% [markdown]
# # Questions to ask

# %% [markdown]
# 1) What is the frequency of words?
#     - Are the words with the highest frequency stop words? Do they provide insights?

# %%
# adding length of comments and word count of each comment
unpickled_df['comment_len'] = unpickled_df['clean_text'].astype(str).swifter.apply(len)
unpickled_df['word_count'] = unpickled_df['clean_text'].swifter.apply(lambda x: len(str(x).split()))
unpickled_df['word_split'] = unpickled_df['clean_text'].swifter.apply(lambda x: str(x).split())

# %%
#Check stopwords currently in list
print(stopword_list)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'nor', 'only', 'own', 'same', 'so', 'than', 'too', 'very
# ...

# %%
# Create function to strip punctuation
def strip_punctuation(s):
    return ''.join(c for c in s if c not in punctuation)

# %%
#update stopword list to remove punctuation
stopword_list_updated = [strip_punctuation(word) for word in stopword_list]

# %%
#Check stopwords currently in list
print(stopword_list_updated)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'youre', 'youve', 'youll', 'youd', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'shes', 'her', 'hers', 'herself', 'it', 'its', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'thatll', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'nor', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's',
# ...

# %%
# All reviews:
text = " ".join(comment for comment in unpickled_df.clean_text)
print ("There are {} words in the combination of all comments.".format(len(text)))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# There are 137356209 words in the combination of all comments.

# %% [markdown]
# Using a word cloud doesn't really give much insight. Looking at the image above, I believe I can remove the stop words listed previously to clean up possible noise.

# %%
unpickled_df.clean_text.head()
# Out:
# 4                   haha you guys are a bunch of losers
# 11    this is a great story man i wonder if the pers...
# 19    angry trolls misogynists and racists oh my it ...
# 20    nice to some attempts to try to make comments ...
# 31    yet call out all muslims for the acts of a few...
# Name: clean_text, dtype: object

# %%
unpickled_df.word_split.head()
# Out:
# 4          [haha, you, guys, are, a, bunch, of, losers]
# 11    [this, is, a, great, story, man, i, wonder, if...
# 19    [angry, trolls, misogynists, and, racists, oh,...
# 20    [nice, to, some, attempts, to, try, to, make, ...
# 31    [yet, call, out, all, muslims, for, the, acts,...
# Name: word_split, dtype: object

# %%
# make list of all the words across all comments
all_words_unp = list(itertools.chain(*unpickled_df['word_split']))

# %%
# Create counter
counts_all_words_unp = collections.Counter(all_words_unp)

counts_all_words_unp.most_common(15)
# Out:
# [('the', 1247094),
#  ('to', 699397),
#  ('and', 621007),
#  ('of', 581637),
#  ('a', 524549),
#  ('is', 414978),
#  ('in', 380754),
#  ('that', 358912),
#  ('you', 247352),
#  ('for', 243612),
#  ('i', 242477),
#  ('it', 233682),
#  ('are', 208776),
#  ('not', 200376),
#  ('be', 166659)]

# %% [markdown]
# Looking at the most common words, they all appear to be noise created by stop words. By removing them, the noise should decrease.

# %%
# function to remove stop words
def remove_stopwords(list_of_words):
    words = [w for w in list_of_words if not w in stopword_list_updated]
    return words

# %%
unpickled_df['clean_text_no_stpwd'] = unpickled_df['word_split'].swifter.apply(remove_stopwords)

# %%
unpickled_df.clean_text.head()
# Out:
# 4                   haha you guys are a bunch of losers
# 11    this is a great story man i wonder if the pers...
# 19    angry trolls misogynists and racists oh my it ...
# 20    nice to some attempts to try to make comments ...
# 31    yet call out all muslims for the acts of a few...
# Name: clean_text, dtype: object

# %% [markdown]
# We'll take another look at the 15 most frequent words and the word cloud without the any of the stopwords.

# %%
# All reviews:
text = " ".join(word for comment in unpickled_df.clean_text_no_stpwd for word in comment)
print ("There are {} words in the combination of all comments.".format(len(text)))

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# There are 92718936 words in the combination of all comments.

# %%
# make list of all the words across all comments
all_words_unp = list(itertools.chain(*unpickled_df['clean_text_no_stpwd']))

# %%
# Create counter
counts_all_words_unp = collections.Counter(all_words_unp)

counts_all_words_unp.most_common(15)
# Out:
# [('not', 200376),
#  ('people', 85660),
#  ('no', 81306),
#  ('would', 76687),
#  ('one', 69369),
#  ('like', 65480),
#  ('us', 50071),
#  ('trump', 49895),
#  ('get', 45222),
#  ('women', 43755),
#  ('think', 40701),
#  ('many', 40670),
#  ('time', 37218),
#  ('know', 36982),
#  ('even', 36182)]

# %% [markdown]
# 2)
